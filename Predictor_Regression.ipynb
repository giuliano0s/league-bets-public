# %% [markdown]
# # SETUP

# %% [markdown]
# Data to export:
# - regionsStats
# - regionsTrainData
# - base_models
# - regionsFeatureCols
#
# To do:
#  - plotOverview
#  - update notebook
#  - streamlit interface for use

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats
import random

from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, RepeatedKFold, cross_val_score
import sklearn.metrics as skm
from sklearn.metrics import accuracy_score
from sklearn.cluster import AffinityPropagation as AP
from sklearn.preprocessing import MinMaxScaler
from sklearn.covariance import EllipticEnvelope

from sklearn.ensemble import GradientBoostingRegressor, IsolationForest, RandomForestRegressor
from sklearn.linear_model import ElasticNet, SGDRegressor, BayesianRidge, LinearRegression
from sklearn.svm import SVR, OneClassSVM
from catboost import CatBoostRegressor
from sklearn.kernel_ridge import KernelRidge
from xgboost.sklearn import XGBRegressor
from lightgbm import LGBMRegressor

import re
import time
import datetime as dt
import json

import sys
import os
sys.path.append(os.path.abspath
                (os.path.join
                 (os.path.dirname("constants.py"), '..')))
from constants import *
from scripts import *

import warnings
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

hide_toggle()
# Out:
#         <script>
#             function code_toggle_15793099756193309762() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_15793099756193309762()">Toggle show/hide</a>

# %% [markdown]
# # FUNCTIONS

# %%
def matchListToDfs(df):
    matchListDateFilter = (df[df['Date'] >= pd.to_datetime('2019-7-01',format='%Y-%m-%d')]
                                        .reset_index(drop=True).copy())
    matchListDateFilter['realSemesterYear'] = (matchListDateFilter['realSemester'].astype(str)
                                               +matchListDateFilter['realYear'].astype(str))
    matchListDateFilter['tournament_id'] = (matchListDateFilter['TournamentRegion'].astype(str)
                                               +matchListDateFilter['realSemesterYear'].astype(str))
    
    playerMatchList = matchListDateFilter.copy()
    teamMatchList = matchListDateFilter.copy()

    for color in ['Blue','Red']:
        for feature in meanFeatures:
                teamMatchList[f'Team_{color}_{feature}'] = (matchListDateFilter[[f"{position}_{color}_{feature}" for position in positions]]
                                                        .mean(skipna=True,axis=1).copy())
                teamMatchList.drop([f"{position}_{color}_{feature}" for position in positions],axis=1,inplace=True)

        for feature in sumFeatures:
                teamMatchList[f'Team_{color}_{feature}'] = (matchListDateFilter[[f"{position}_{color}_{feature}" for position in positions]]
                                                        .sum(skipna=True,axis=1).copy())
                teamMatchList.drop([f"{position}_{color}_{feature}" for position in positions],axis=1,inplace=True)

        teamMatchList.drop([f"{position}_{color}" for position in positions],axis=1,inplace=True)
        
    return playerMatchList, teamMatchList

def regionLists(df, currentYear):
    regions = df['TournamentRegion'].unique()
    regionsToFeed = [x for x in df['TournamentRegion'].unique()]
    regionsFilterTemp = ([x for x in regions if currentYear in (df[df['TournamentRegion']==x])['realYear'].unique()
                                            and currentYear-1 in (df[df['TournamentRegion']==x])['realYear'].unique()])
    regionsToPredict = []
    for region in regionsFilterTemp:
        regionsFilterSize = df[(df['realYear']==currentYear) & (df['TournamentRegion']==region)]
        if len(regionsFilterSize)>=10:
            regionsToPredict.append(region)

    #regionsToPredict = regionsToPredict[0:5]
    
    return regions, regionsToFeed, regionsToPredict

def filterNan(df,dropType):
    dfRet = df
    
    if dropType==0:
        dfRet = dfRet.dropna()
        
    elif dropType==1:
        for col in dfRet.columns:
            dfRet[col] = dfRet[col].fillna(0)
            
    return dfRet

hide_toggle()
# Out:
#         <script>
#             function code_toggle_935380438177908311() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_935380438177908311()">Toggle show/hide</a>

# %% [markdown]
# # LOAD

# %%
teamDataTable = pd.read_pickle("Data/raw_data/teamDataTable.pkl")
playerDataTable = pd.read_pickle("Data/raw_data/playerDataTable.pkl")

matchList = pd.read_pickle("Data/raw_data/matchList.pkl")
matchListFill = pd.read_pickle("Data/raw_data/matchListFill.pkl")

teamMatchList = pd.read_pickle("Data/raw_data/teamMatchList.pkl")
playerMatchList = pd.read_pickle("Data/raw_data/playerMatchList.pkl")

regionsStats = pd.read_pickle("./Data/raw_data/regionsStats.pkl")

with open(f'./Data/raw_data/regionsFeatureCols.json', 'r') as fp:
    regionsFeatureCols = json.load(fp)
with open(f'./Data/raw_data/regionsTrainData.json', 'r') as fp:
    regionsTrainData = json.load(fp)

# %% [markdown]
# # PREPROCESS

# %%
#            0          1
dfsFilter = [matchList, matchListFill]
dfTemp = dfsFilter[1].copy()

playerMatchList, teamMatchList = matchListToDfs(dfTemp)

#             0              1
dfsContent = [teamMatchList, playerMatchList]
dfToSplit = dfsContent[0].copy()

print(f'main df size: {len(dfToSplit)}')

base_models = [
              GradientBoostingRegressor(loss='absolute_error') #0
              ,ElasticNet() #1
              ,BayesianRidge() #2
              ,LinearRegression() #3
              ,SVR() #4
              ,CatBoostRegressor(verbose=False) #5
              ,KernelRidge() #6
              ,XGBRegressor() #7
              ,RandomForestRegressor() #8
              ]

currentTarget = 'totalKills'
defaultModel = 4
infoCols = ['Date','tournament_id',currentTarget,'TournamentRegion']
featureCols = [x for x in dfToSplit.columns if x not in offCols+infoCols]

regions, regionsToFeed, regionsToPredict = regionLists(dfToSplit, currentYear)
# Out:
# main df size: 26314

# %% [markdown]
# # SKLEARN

# %%
regionsStats = pd.DataFrame(columns=['region','model','size'])
regionsStats['region'] = regionsToPredict
regionsList = regionsStats['region']
regionsStats['model'] = defaultModel

regionsTrainData = dict(zip(regionsList,regionsList.apply(lambda x: [x])))
regionsStats['accuracy_0'] = np.nan
regionsStats['accuracy_1'] = np.nan
regionsStats['accuracy_2'] = np.nan
regionsStats['drop_nan_type'] = 0

# %% [markdown]
# ### TRAIN DATA SELECTION

# %%
# %%time

regionsTrainData = dict(zip(regionsList,regionsList.apply(lambda x: [x])))
regionsStats['accuracy_0'] = np.nan

for n,region in enumerate(regionsToPredict):
    print('=========\n')
    regionFinalAcc = (regionsStats[regionsStats['region']==region])['accuracy_0'].iloc[0]
    print(f'[{n+1} of {len(regionsToPredict)}] region {region} -> {round(regionFinalAcc,3)}:\n')
    tempTournamentId = region+currentSemesterYear
    
    regionsToTest = [x for x in regionsToFeed]
    regionsToTest.remove(region)
    random.shuffle(regionsToTest)
    for nn,regionToTest in enumerate(regionsToTest):
        regionsTrainData[region].append(regionToTest)
        
        dfSklearnRegions = dfToSplit[dfToSplit['TournamentRegion'].isin(regionsTrainData[region])].copy()
        dfSklearnRegions = dfSklearnRegions.sort_values(by='Date',ascending=True).copy()
        dfSklearnRegions = filterNan(dfSklearnRegions,regionsStats['drop_nan_type'][n])
        
        xtrain,ytrain,xtest,ytest = train_test_split2(dfSklearnRegions,tempTournamentId,currentTarget,verbose=False)
        
        region_model_number = (regionsStats[regionsStats['region']==region])['model'].iloc[0]
        region_model = base_models[region_model_number]
        region_model.fit(xtrain, ytrain)
        pred = region_model.predict(xtest)
        
        metric = round(skm.mean_absolute_error(ytest, pred),2)
        
        if metric < regionFinalAcc or np.isnan(regionFinalAcc):
            regionFinalAcc = metric
            
            print(f'{round(regionFinalAcc,3)} -> {regionToTest} added                                       ')
        else:
            regionsTrainData[region].remove(regionToTest)
            
        print(f'[{nn+1} of {len(regionsToTest)}] testing: {regionToTest}                        ',end='\r')
    
    regionsStats['accuracy_0'][n] = regionFinalAcc
    regionsStats['size'][n] = len(pred)
    
    print(f'\n\naccuracy: {round(regionFinalAcc,3)}')
    print(f'{region} train data: {regionsTrainData[region]}\nlen:{len(regionsTrainData[region])}')
    print(f'test data len: {len(pred)}\n')
    
printFinalResults(regionsStats, 'accuracy_0')

hide_toggle()
# Out:
# =========
#
# [1 of 22] region LPL -> nan:
#
# 7.21 -> EU added
# 7.19 -> Demacia added
# 7.16 -> LCO added
# 7.13 -> World added
# [53 of 53] testing: PCS
#
# accuracy: 7.13
# LPL train data: ['LPL', 'EU', 'Demacia', 'LCO', 'World']
# len:5
# test data len: 119
#
# =========
#
# [2 of 22] region LCK -> nan:
#
# 5.76 -> SuperLiga_Tier2 added
# 5.74 -> LVP2 added
# 5.73 -> LJL added
# 5.7 -> LCS added
# 5.69 -> Iberian added
# [53 of 53] testing: Demacia
#
# accuracy: 5.69
# LCK train data: ['LCK', 'SuperLiga_Tier2', 'LVP2', 'LJL', 'LCS', 'Iberian']
# len:6
# test data len: 248
#
# =========
#
# [3 of 22] region PCS -> nan:
#
# 6.35 -> NLC added
# 6.34 -> BRCC added
# 6.33 -> REL added
# 6.31 -> OPL added
# 6.29 -> Kespa added
# 6.28 -> LVP2 added
# 6.26 -> LMS added
# 6.18 -> LCK added
# 6.17 -> Prime_Tier2 added
# 6.15 -> Baltic added
# 6.13 -> LLA added
# [53 of 53] testing: Turkey_Tier2
#
# accuracy: 6.13
# PCS train data: ['PCS', 'NLC', 'BRCC', 'REL', 'OPL', 'Kespa', 'LVP2', 'LMS', 'LCK', 'Prime_Tier2', 'Baltic', 'LLA']
# len:12
# test data len: 105
#
# =========
#
# [4 of 22] region VCS -> nan:
#
# 6.54 -> LMS added
# 6.4 -> LPLOL added
# 6.26 -> TCL added
# 6.18 -> LVP added
# 6.15 -> LLA added
# 6.14 -> Turkey_Tier2 added
# 6.13 -> LJL added
# 6.12 -> LEC added
# [53 of 53] testing: LCO
#
# accuracy: 6.12
# VCS train data: ['VCS', 'LMS', 'LPLOL', 'TCL', 'LVP', 'LLA', 'Turkey_Tier2', 'LJL', 'LEC']
# len:9
# test data len: 92
#
# =========
#
# [5 of 22] region Ultraliga -> nan:
#
# 7.66 -> EBL added
# 7.6 -> LCS_Tier2 added
# 7.44 -> LCO added
# 7.35 -> EU added
# 7.32 -> Elite_Tier2 added
# 7.3 -> LMS added
# 7.23 -> Arabian added
# 7.21 -> LPLOL added
# 7.16 -> GLL added
# 7.13 -> PG added
# 7.11 -> Dutch added
# 7.05 -> VCS added
# 7.04 -> OPL added
# [53 of 53] testing: Hitpoint_Tier2
#
# accuracy: 7.04
# Ultraliga train data: ['Ultraliga', 'EBL', 'LCS_Tier2', 'LCO', 'EU', 'Elite_Tier2', 'LMS', 'Arabian', 'LPLOL', 'GLL', 'PG', 'Dutch', 'VCS', 'OPL']
# len:14
# test data len: 108
#
# =========
#
# [6 of 22] region LLA -> nan:
#
# 6.57 -> LCS_Tier2 added
# 6.5 -> LJL added
# 6.48 -> LCS added
# 6.47 -> Kespa added
# 6.46 -> World added
# 6.45 -> BRCC added
# 6.44 -> NACL added
# [53 of 53] testing: LPLOL
#
# accuracy: 6.44
# LLA train data: ['LLA', 'LCS_Tier2', 'LJL', 'LCS', 'Kespa', 'World', 'BRCC', 'NACL']
# len:8
# test data len: 79
#
# =========
#
# [7 of 22] region TCL -> nan:
#
# 6.66 -> GLL added
# 6.57 -> Ultraliga added
# 6.56 -> LMS added
# 6.55 -> Iberian added
# 6.54 -> EBL added
# 6.52 -> NACL added
# 6.47 -> CK added
# 6.46 -> LJL added
# 6.45 -> SuperLiga added
# 6.44 -> LVP added
# 6.43 -> Turkey_Tier2 added
# 6.42 -> SuperLiga_Tier2 added
# 6.39 -> LCK added
# [53 of 53] testing: LVP2
#
# accuracy: 6.39
# TCL train data: ['TCL', 'GLL', 'Ultraliga', 'LMS', 'Iberian', 'EBL', 'NACL', 'CK', 'LJL', 'SuperLiga', 'LVP', 'Turkey_Tier2', 'SuperLiga_Tier2', 'LCK']
# len:14
# test data len: 69
#
# =========
#
# [8 of 22] region LFL -> nan:
#
# 6.23 -> GLL added
# 6.21 -> Mid-Season added
# 5.92 -> PCS added
# 5.86 -> LPL added
# 5.84 -> LLA added
# 5.83 -> CK added
# 5.82 -> CBLOL_Tier2 added
# 5.81 -> Ultraliga added
# 5.8 -> SuperLiga added
# [53 of 53] testing: NA_Tier2
#
# accuracy: 5.8
# LFL train data: ['LFL', 'GLL', 'Mid-Season', 'PCS', 'LPL', 'LLA', 'CK', 'CBLOL_Tier2', 'Ultraliga', 'SuperLiga']
# len:10
# test data len: 204
#
# =========
#
# [9 of 22] region Prime -> nan:
#
# 5.86 -> NLC added
# 5.85 -> Demacia added
# 5.84 -> REL added
# 5.64 -> LCS added
# 5.63 -> World added
# 5.62 -> SuperLiga added
# 5.61 -> LVP added
# 5.6 -> Baltic added
# 5.59 -> LEC added
# 5.58 -> Prime_Tier2 added
# 5.57 -> LLA added
# [53 of 53] testing: LCO
#
# accuracy: 5.57
# Prime train data: ['Prime', 'NLC', 'Demacia', 'REL', 'LCS', 'World', 'SuperLiga', 'LVP', 'Baltic', 'LEC', 'Prime_Tier2', 'LLA']
# len:12
# test data len: 110
#
# =========
#
# [10 of 22] region LJL -> nan:
#
# 5.71 -> Belgian added
# 5.7 -> REL added
# 5.56 -> Turkey_Tier2 added
# 5.55 -> Asia added
# 5.53 -> NACL added
# 5.46 -> LCS added
# 5.45 -> PCS added
# 5.43 -> LMS added
# [53 of 53] testing: EBL
#
# accuracy: 5.43
# LJL train data: ['LJL', 'Belgian', 'REL', 'Turkey_Tier2', 'Asia', 'NACL', 'LCS', 'PCS', 'LMS']
# len:9
# test data len: 133
#
# =========
#
# [11 of 22] region NLC -> nan:
#
# 8.19 -> BRCC added
# 8.17 -> World added
# 8.11 -> CBLOL added
# 8.09 -> PG added
# 8.08 -> LCS_Tier2 added
# 8.05 -> Elite_Tier2 added
# 7.99 -> LJL added
# 7.97 -> Turkey_Tier2 added
# [53 of 53] testing: PCS
#
# accuracy: 7.97
# NLC train data: ['NLC', 'BRCC', 'World', 'CBLOL', 'PG', 'LCS_Tier2', 'Elite_Tier2', 'LJL', 'Turkey_Tier2']
# len:9
# test data len: 70
#
# =========
#
# [12 of 22] region CBLOL_Tier2 -> nan:
#
# 6.72 -> MSI added
# 6.64 -> MCR added
# 6.53 -> GLL added
# 6.52 -> Elite_Tier2 added
# 6.51 -> VCS added
# [53 of 53] testing: LVP
#
# accuracy: 6.51
# CBLOL_Tier2 train data: ['CBLOL_Tier2', 'MSI', 'MCR', 'GLL', 'Elite_Tier2', 'VCS']
# len:6
# test data len: 90
#
# =========
#
# [13 of 22] region EBL -> nan:
#
# 6.63 -> LJL_Tier2 added
# 6.44 -> LLA added
# 6.42 -> LST added
# 6.39 -> LVP added
# 6.36 -> OPL added
# 6.34 -> Kespa added
# 6.31 -> TCL added
# [53 of 53] testing: Turkey_Tier2
#
# accuracy: 6.31
# EBL train data: ['EBL', 'LJL_Tier2', 'LLA', 'LST', 'LVP', 'OPL', 'Kespa', 'TCL']
# len:8
# test data len: 69
#
# =========
#
# [14 of 22] region Hitpoint_Tier2 -> nan:
#
# 9.09 -> Arabian added
# 8.83 -> LEC added
# 8.82 -> Kespa added
# 8.8 -> LMS added
# 8.79 -> Mid-Season added
# 8.77 -> GLL added
# 8.76 -> LCS added
# 8.74 -> PG added
# 8.69 -> Trinity added
# 8.68 -> Demacia added
# 8.67 -> NLC added
# 8.66 -> KeSPA added
# 8.65 -> Baltic added
# [53 of 53] testing: NACL
#
# accuracy: 8.65
# Hitpoint_Tier2 train data: ['Hitpoint_Tier2', 'Arabian', 'LEC', 'Kespa', 'LMS', 'Mid-Season', 'GLL', 'LCS', 'PG', 'Trinity', 'Demacia', 'NLC', 'KeSPA', 'Baltic']
# len:14
# test data len: 63
#
# =========
#
# [15 of 22] region Elite_Tier2 -> nan:
#
# 8.41 -> REL added
# 8.37 -> Belgian added
# 8.28 -> Arabian added
# 8.25 -> Demacia added
# 8.23 -> Mid-Season added
# 8.22 -> Baltic added
# 8.21 -> LCL added
# 8.19 -> Dutch added
# 8.15 -> MCR added
# 8.14 -> Hitpoint_Tier2 added
# [53 of 53] testing: LCS_Tier2
#
# accuracy: 8.14
# Elite_Tier2 train data: ['Elite_Tier2', 'REL', 'Belgian', 'Arabian', 'Demacia', 'Mid-Season', 'Baltic', 'LCL', 'Dutch', 'MCR', 'Hitpoint_Tier2']
# len:11
# test data len: 65
#
# =========
#
# [16 of 22] region GLL -> nan:
#
# 6.17 -> PCS added
# 6.11 -> Prime added
# 6.1 -> MSI added
# 6.09 -> MCR added
# 6.07 -> PG added
# 6.06 -> Dutch added
# 6.04 -> VCS added
# 6.02 -> Baltic added
# 6.01 -> Hitpoint_Tier2 added
# [53 of 53] testing: Turkey_Tier2
#
# accuracy: 6.01
# GLL train data: ['GLL', 'PCS', 'Prime', 'MSI', 'MCR', 'PG', 'Dutch', 'VCS', 'Baltic', 'Hitpoint_Tier2']
# len:10
# test data len: 69
#
# =========
#
# [17 of 22] region LEC -> nan:
#
# 6.82 -> LCS added
# 6.53 -> Hitpoint_Tier2 added
# 6.51 -> LPLOL added
# 6.5 -> Elite_Tier2 added
# 6.47 -> Prime added
# 6.46 -> LJL_Tier2 added
# 6.45 -> LCO added
# 6.44 -> Turkey_Tier2 added
# 6.43 -> LPL added
# 6.42 -> CBLOL_Tier2 added
# 6.41 -> EU added
# 6.4 -> PG added
# 6.39 -> VCS added
# [53 of 53] testing: TCL
#
# accuracy: 6.39
# LEC train data: ['LEC', 'LCS', 'Hitpoint_Tier2', 'LPLOL', 'Elite_Tier2', 'Prime', 'LJL_Tier2', 'LCO', 'Turkey_Tier2', 'LPL', 'CBLOL_Tier2', 'EU', 'PG', 'VCS']
# len:14
# test data len: 130
#
# =========
#
# [18 of 22] region CBLOL -> nan:
#
# 6.66 -> PG added
# 6.63 -> NACL added
# 6.61 -> World added
# 6.59 -> LEC added
# 6.57 -> LLA added
# 6.55 -> LPLOL added
# 6.54 -> OPL added
# 6.51 -> LJL added
# 6.5 -> LCS_Tier2 added
# 6.48 -> NLC added
# 6.47 -> MCR added
# 6.46 -> Elite_Tier2 added
# [53 of 53] testing: Prime_Tier2
#
# accuracy: 6.46
# CBLOL train data: ['CBLOL', 'PG', 'NACL', 'World', 'LEC', 'LLA', 'LPLOL', 'OPL', 'LJL', 'LCS_Tier2', 'NLC', 'MCR', 'Elite_Tier2']
# len:13
# test data len: 90
#
# =========
#
# [19 of 22] region LPLOL -> nan:
#
# 7.31 -> TCL added
# 7.24 -> LPL added
# 7.22 -> LFL added
# 7.21 -> CK added
# 7.19 -> NLC added
# 7.16 -> Hitpoint_Tier2 added
# 7.15 -> OPL added
# 7.14 -> SuperLiga_Tier2 added
# 7.13 -> LVP added
# [53 of 53] testing: LVP
#
# accuracy: 7.13
# LPLOL train data: ['LPLOL', 'TCL', 'LPL', 'LFL', 'CK', 'NLC', 'Hitpoint_Tier2', 'OPL', 'SuperLiga_Tier2', 'LVP']
# len:10
# test data len: 67
#
# =========
#
# [20 of 22] region LCS -> nan:
#
# 5.58 -> World added
# 5.57 -> Iberian added
# 5.55 -> LLA added
# [53 of 53] testing: OPL
#
# accuracy: 5.55
# LCS train data: ['LCS', 'World', 'Iberian', 'LLA']
# len:4
# test data len: 93
#
# =========
#
# [21 of 22] region PG -> nan:
#
# 8.1 -> NLC added
# 8.03 -> Trinity added
# 7.84 -> GLL added
# 7.82 -> Elite_Tier2 added
# 7.8 -> SuperLiga_Tier2 added
# 7.78 -> MCR added
# 7.77 -> EU added
# [53 of 53] testing: EU
#
# accuracy: 7.77
# PG train data: ['PG', 'NLC', 'Trinity', 'GLL', 'Elite_Tier2', 'SuperLiga_Tier2', 'MCR', 'EU']
# len:8
# test data len: 68
#
# =========
#
# [22 of 22] region LCO -> nan:
#
# 6.7 -> Prime added
# 6.44 -> LCK added
# 6.23 -> Turkey_Tier2 added
# 6.21 -> LVP2 added
# 6.2 -> NACL added
# 6.18 -> LPL added
# 6.16 -> Ultraliga added
# 6.15 -> NA_Tier2 added
# 6.14 -> LJL_Tier2 added
# 6.1 -> CBLOL_Tier2 added
# 6.09 -> LVP added
# 6.04 -> Trinity added
# [53 of 53] testing: VCS
#
# accuracy: 6.04
# LCO train data: ['LCO', 'Prime', 'LCK', 'Turkey_Tier2', 'LVP2', 'NACL', 'LPL', 'Ultraliga', 'NA_Tier2', 'LJL_Tier2', 'CBLOL_Tier2', 'LVP', 'Trinity']
# len:13
# test data len: 23
#
# ===============================
#
# mean accuracy: 6.576
# avg df len: 98.36363636363636
#
# CPU times: total: 8min 58s
# Wall time: 9min 2s
#         <script>
#             function code_toggle_9541281493352656709() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_9541281493352656709()">Toggle show/hide</a>

# %% [markdown]
# ### DROP NAN VALUES

# %%
# %%time

for n,region in enumerate(regionsToPredict):
    print('=========\n')
    bestDropMetric = (regionsStats[regionsStats['region']==region])['accuracy_0'].iloc[0]
    bestDropType = regionsStats['drop_nan_type'][n]
    print(f'[{n+1} of {len(regionsToPredict)}] region {region} -> {round(regionFinalAcc,3)}:')
    tempTournamentId = region+currentSemesterYear
    
    for dropType in range(0,2):
        dfSklearnRegions = dfToSplit[dfToSplit['TournamentRegion'].isin(regionsTrainData[region])].copy()
        dfSklearnRegions = dfSklearnRegions.sort_values(by='Date',ascending=True).copy()
        dfSklearnRegions = filterNan(dfSklearnRegions, dropType)

        xtrain,ytrain,xtest,ytest = train_test_split2(dfSklearnRegions,tempTournamentId,currentTarget,verbose=False)
        
        region_model_number = (regionsStats[regionsStats['region']==region])['model'].iloc[0]
        region_model = base_models[region_model_number]
        region_model.fit(xtrain, ytrain)
        pred = region_model.predict(xtest)
        
        metric = round(skm.mean_absolute_error(ytest, pred),2)
        print(f'\ntesting dropType: {dropType}\naccuracy: {metric}')
        if metric < bestDropMetric or np.isnan(bestDropMetric):
            bestDropMetric = metric
            bestDropType = dropType
            print(f'dropType changed to {dropType}: {round(bestDropMetric,3)}')
    
    regionsStats['accuracy_0'][n] = bestDropMetric
    regionsStats['drop_nan_type'][n] = bestDropType
    print(f'\nfinal accuracy: {bestDropMetric}\nfinal droptype: {bestDropType}\n')
    print(f'test data len: {len(pred)}\n')
    
printFinalResults(regionsStats, 'accuracy_0')

hide_toggle()
# Out:
# =========
#
# [1 of 22] region LPL -> 6.04:
#
# testing dropType: 0
# accuracy: 7.13
#
# testing dropType: 1
# accuracy: 6.59
# dropType changed to 1: 6.59
#
# final accuracy: 6.59
# final droptype: 1
#
# test data len: 329
#
# =========
#
# [2 of 22] region LCK -> 6.04:
#
# testing dropType: 0
# accuracy: 5.69
#
# testing dropType: 1
# accuracy: 5.7
#
# final accuracy: 5.69
# final droptype: 0
#
# test data len: 248
#
# =========
#
# [3 of 22] region PCS -> 6.04:
#
# testing dropType: 0
# accuracy: 6.13
#
# testing dropType: 1
# accuracy: 6.13
#
# final accuracy: 6.13
# final droptype: 0
#
# test data len: 105
#
# =========
#
# [4 of 22] region VCS -> 6.04:
#
# testing dropType: 0
# accuracy: 6.12
#
# testing dropType: 1
# accuracy: 6.12
#
# final accuracy: 6.12
# final droptype: 0
#
# test data len: 92
#
# =========
#
# [5 of 22] region Ultraliga -> 6.04:
#
# testing dropType: 0
# accuracy: 7.04
#
# testing dropType: 1
# accuracy: 7.05
#
# final accuracy: 7.04
# final droptype: 0
#
# test data len: 108
#
# =========
#
# [6 of 22] region LLA -> 6.04:
#
# testing dropType: 0
# accuracy: 6.44
#
# testing dropType: 1
# accuracy: 6.45
#
# final accuracy: 6.44
# final droptype: 0
#
# test data len: 79
#
# =========
#
# [7 of 22] region TCL -> 6.04:
#
# testing dropType: 0
# accuracy: 6.39
#
# testing dropType: 1
# accuracy: 6.39
#
# final accuracy: 6.39
# final droptype: 0
#
# test data len: 69
#
# =========
#
# [8 of 22] region LFL -> 6.04:
#
# testing dropType: 0
# accuracy: 5.8
#
# testing dropType: 1
# accuracy: 5.8
#
# final accuracy: 5.8
# final droptype: 0
#
# test data len: 204
#
# =========
#
# [9 of 22] region Prime -> 6.04:
#
# testing dropType: 0
# accuracy: 5.57
#
# testing dropType: 1
# accuracy: 5.58
#
# final accuracy: 5.57
# final droptype: 0
#
# test data len: 110
#
# =========
#
# [10 of 22] region LJL -> 6.04:
#
# testing dropType: 0
# accuracy: 5.43
#
# testing dropType: 1
# accuracy: 5.45
#
# final accuracy: 5.43
# final droptype: 0
#
# test data len: 133
#
# =========
#
# [11 of 22] region NLC -> 6.04:
#
# testing dropType: 0
# accuracy: 7.97
#
# testing dropType: 1
# accuracy: 7.97
#
# final accuracy: 7.97
# final droptype: 0
#
# test data len: 70
#
# =========
#
# [12 of 22] region CBLOL_Tier2 -> 6.04:
#
# testing dropType: 0
# accuracy: 6.51
#
# testing dropType: 1
# accuracy: 6.51
#
# final accuracy: 6.51
# final droptype: 0
#
# test data len: 90
#
# =========
#
# [13 of 22] region EBL -> 6.04:
#
# testing dropType: 0
# accuracy: 6.31
#
# testing dropType: 1
# accuracy: 6.31
#
# final accuracy: 6.31
# final droptype: 0
#
# test data len: 69
#
# =========
#
# [14 of 22] region Hitpoint_Tier2 -> 6.04:
#
# testing dropType: 0
# accuracy: 8.65
#
# testing dropType: 1
# accuracy: 8.68
#
# final accuracy: 8.65
# final droptype: 0
#
# test data len: 63
#
# =========
#
# [15 of 22] region Elite_Tier2 -> 6.04:
#
# testing dropType: 0
# accuracy: 8.14
#
# testing dropType: 1
# accuracy: 8.18
#
# final accuracy: 8.14
# final droptype: 0
#
# test data len: 65
#
# =========
#
# [16 of 22] region GLL -> 6.04:
#
# testing dropType: 0
# accuracy: 6.01
#
# testing dropType: 1
# accuracy: 6.01
#
# final accuracy: 6.01
# final droptype: 0
#
# test data len: 69
#
# =========
#
# [17 of 22] region LEC -> 6.04:
#
# testing dropType: 0
# accuracy: 6.39
#
# testing dropType: 1
# accuracy: 6.42
#
# final accuracy: 6.39
# final droptype: 0
#
# test data len: 130
#
# =========
#
# [18 of 22] region CBLOL -> 6.04:
#
# testing dropType: 0
# accuracy: 6.46
#
# testing dropType: 1
# accuracy: 6.47
#
# final accuracy: 6.46
# final droptype: 0
#
# test data len: 90
#
# =========
#
# [19 of 22] region LPLOL -> 6.04:
#
# testing dropType: 0
# accuracy: 7.13
#
# testing dropType: 1
# accuracy: 7.13
#
# final accuracy: 7.13
# final droptype: 0
#
# test data len: 67
#
# =========
#
# [20 of 22] region LCS -> 6.04:
#
# testing dropType: 0
# accuracy: 5.55
#
# testing dropType: 1
# accuracy: 5.55
#
# final accuracy: 5.55
# final droptype: 0
#
# test data len: 93
#
# =========
#
# [21 of 22] region PG -> 6.04:
#
# testing dropType: 0
# accuracy: 7.77
#
# testing dropType: 1
# accuracy: 7.77
#
# final accuracy: 7.77
# final droptype: 0
#
# test data len: 68
#
# =========
#
# [22 of 22] region LCO -> 6.04:
#
# testing dropType: 0
# accuracy: 6.04
#
# testing dropType: 1
# accuracy: 6.02
# dropType changed to 1: 6.02
#
# final accuracy: 6.02
# final droptype: 1
#
# test data len: 23
#
# ===============================
#
# mean accuracy: 6.55
# avg df len: 98.36363636363636
#
# CPU times: total: 33 s
# Wall time: 33.2 s
#         <script>
#             function code_toggle_7012529258671957817() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_7012529258671957817()">Toggle show/hide</a>

# %% [markdown]
# ### FEATURE SELECTION

# %%
# %%time

regionsFeatureCols = dict(zip(regionsList,[0]*len(regionsList)))
for key in regionsFeatureCols:
    regionsFeatureCols[key] = featureCols.copy()

regionsStats['accuracy_1'] = np.nan

for n,region in enumerate(regionsToPredict):
    print('=========\n')
    regionFinalAcc = (regionsStats[regionsStats['region']==region])['accuracy_0'].iloc[0]
    bestDropType = regionsStats['drop_nan_type'][n]
    tempTournamentId = region+currentSemesterYear
    
    region_model_number = (regionsStats[regionsStats['region']==region])['model'].iloc[0]
    region_model = base_models[region_model_number]
    regionDataList = regionsTrainData[region]
    
    print(f'[{n+1} of {len(regionsToPredict)}] region {region} -> {round(regionFinalAcc,3)}:\n')
    print(f'model: {region_model_number}')
    
    initialFeatures = regionsFeatureCols[region].copy()
    for nn,feature in enumerate(initialFeatures):

        regionsFeatureCols[region].remove(feature)
        dfSklearnRegions = dfToSplit[regionsFeatureCols[region]+infoCols].copy()
        dfSklearnRegions = dfSklearnRegions[dfSklearnRegions['TournamentRegion'].isin(regionDataList)].copy()
        dfSklearnRegions = dfSklearnRegions.sort_values(by='Date',ascending=True).copy()
        dfSklearnRegions = filterNan(dfSklearnRegions, dropType)

        xtrain,ytrain,xtest,ytest = train_test_split2(dfSklearnRegions,tempTournamentId,currentTarget,verbose=False)
        region_model.fit(xtrain, ytrain)
        
        pred = region_model.predict(xtest)
        metric = round(skm.mean_absolute_error(ytest, pred),2)
        if metric < regionFinalAcc or np.isnan(regionFinalAcc):
            regionFinalAcc = metric
            print(f'{feature} removed for {metric}                                                ')
        else:
            regionsFeatureCols[region].append(feature)
            
        print(f'[{nn+1} of {len(initialFeatures)}] testing: {feature}                        ',end='\r')
    
    regionsStats['accuracy_1'][n] = regionFinalAcc
    regionsStats['size'][n] = len(dfSklearnRegions)
    
    print(f'\n\naccuracy: {round(regionFinalAcc,3)}')
    print(f'{region} feature count: {len(regionsFeatureCols[region])}')
    print(f'test data len: {len(pred)}\n')
    
printFinalResults(regionsStats, 'accuracy_1')

hide_toggle()
# Out:
# =========
#
# [1 of 22] region LPL -> 6.59:
#
# model: 4
# Team_Blue_DPM removed for 6.58
# Team_Red_DPM removed for 6.54
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 6.54
# LPL feature count: 42
# test data len: 329
#
# =========
#
# [2 of 22] region LCK -> 5.69:
#
# model: 4
# Team_Red_DPM removed for 5.68
# Team_Red_XPD@15 removed for 5.67
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 5.67
# LCK feature count: 42
# test data len: 248
#
# =========
#
# [3 of 22] region PCS -> 6.13:
#
# model: 4
# Team_Blue_Win_rate removed for 6.12
# Team_Red_DPM removed for 6.11
# Team_Red_GD@15 removed for 6.1
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 6.1
# PCS feature count: 41
# test data len: 105
#
# =========
#
# [4 of 22] region VCS -> 6.12:
#
# model: 4
# Team_Red_DPM removed for 6.11
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 6.11
# VCS feature count: 43
# test data len: 92
#
# =========
#
# [5 of 22] region Ultraliga -> 7.04:
#
# model: 4
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 7.04
# Ultraliga feature count: 44
# test data len: 108
#
# =========
#
# [6 of 22] region LLA -> 6.44:
#
# model: 4
# Team_Blue_GPM removed for 6.43
# Team_Red_DPM removed for 6.39
# Team_Red_Games removed for 6.38
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 6.38
# LLA feature count: 41
# test data len: 79
#
# =========
#
# [7 of 22] region TCL -> 6.39:
#
# model: 4
# Team_Blue_GD@15 removed for 6.38
# Team_Blue_XPD@15 removed for 6.36
# Team_Red_DPM removed for 6.33
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 6.33
# TCL feature count: 41
# test data len: 69
#
# =========
#
# [8 of 22] region LFL -> 5.8:
#
# model: 4
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 5.8
# LFL feature count: 44
# test data len: 204
#
# =========
#
# [9 of 22] region Prime -> 5.57:
#
# model: 4
# Team_Blue_DPM removed for 5.55
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 5.55
# Prime feature count: 43
# test data len: 110
#
# =========
#
# [10 of 22] region LJL -> 5.43:
#
# model: 4
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 5.43
# LJL feature count: 44
# test data len: 133
#
# =========
#
# [11 of 22] region NLC -> 7.97:
#
# model: 4
# Team_Blue_GPM removed for 7.96
# Team_Blue_Games removed for 7.94
# Team_Red_GPM removed for 7.92
# Team_Red_GD@15 removed for 7.91
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 7.91
# NLC feature count: 40
# test data len: 70
#
# =========
#
# [12 of 22] region CBLOL_Tier2 -> 6.51:
#
# model: 4
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 6.51
# CBLOL_Tier2 feature count: 44
# test data len: 90
#
# =========
#
# [13 of 22] region EBL -> 6.31:
#
# model: 4
# Team_Red_DPM removed for 6.29
# Team_Red_GD@15 removed for 6.28
# Team_Red_Solo_Kills removed for 6.27
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 6.27
# EBL feature count: 41
# test data len: 69
#
# =========
#
# [14 of 22] region Hitpoint_Tier2 -> 8.65:
#
# model: 4
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 8.65
# Hitpoint_Tier2 feature count: 44
# test data len: 63
#
# =========
#
# [15 of 22] region Elite_Tier2 -> 8.14:
#
# model: 4
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 8.14
# Elite_Tier2 feature count: 44
# test data len: 65
#
# =========
#
# [16 of 22] region GLL -> 6.01:
#
# model: 4
# Team_Red_DPM removed for 5.95
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 5.95
# GLL feature count: 43
# test data len: 69
#
# =========
#
# [17 of 22] region LEC -> 6.39:
#
# model: 4
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 6.39
# LEC feature count: 44
# test data len: 130
#
# =========
#
# [18 of 22] region CBLOL -> 6.46:
#
# model: 4
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 6.46
# CBLOL feature count: 44
# test data len: 90
#
# =========
#
# [19 of 22] region LPLOL -> 7.13:
#
# model: 4
# Team_Blue_GPM removed for 7.12
# Team_Blue_DPM removed for 7.06
# Team_Red_GD@15 removed for 7.05
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 7.05
# LPLOL feature count: 41
# test data len: 67
#
# =========
#
# [20 of 22] region LCS -> 5.55:
#
# model: 4
# Team_Blue_DPM removed for 5.54
# Team_Red_XPD@15 removed for 5.53
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 5.53
# LCS feature count: 42
# test data len: 93
#
# =========
#
# [21 of 22] region PG -> 7.77:
#
# model: 4
# Team_Blue_GPM removed for 7.76
# Team_Blue_DPM removed for 7.75
# Team_Red_XPD@15 removed for 7.74
# Team_Red_Games removed for 7.73
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 7.73
# PG feature count: 40
# test data len: 68
#
# =========
#
# [22 of 22] region LCO -> 6.02:
#
# model: 4
# Team_Blue_DPM removed for 6.01
# Team_Blue_XPD@15 removed for 6.0
# Team_Red_DPM removed for 5.93
# [44 of 44] testing: Team_Red_Solo_Kills
#
# accuracy: 5.93
# LCO feature count: 41
# test data len: 23
#
# ===============================
#
# mean accuracy: 6.521
# avg df len: 5376.090909090909
#
# CPU times: total: 13min 7s
# Wall time: 13min 13s
#         <script>
#             function code_toggle_18062224888762266612() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_18062224888762266612()">Toggle show/hide</a>

# %% [markdown]
# ### MODEL SELECTION

# %%
# %%time

regionsStats['accuracy_2'] = np.nan

for n,region in enumerate(regionsToPredict):
    print('=========\n')
    currAcc = (regionsStats[regionsStats['region']==region])['accuracy_1'].iloc[0]
    currModel = (regionsStats[regionsStats['region']==region])['model'].iloc[0]
    bestDropType = regionsStats['drop_nan_type'][n]
    print(f'[{n+1} of {len(regionsToPredict)}] region {region} -> {round(currAcc,3)}:\n')
    print(f'current model: {currModel}\n')
    
    regionDataList = regionsTrainData[region]
    tempTournamentId = region+currentSemesterYear
    dfSklearnRegions = dfToSplit[dfToSplit['TournamentRegion'].isin(regionDataList)].copy()
    dfSklearnRegions = dfSklearnRegions[regionsFeatureCols[region]+infoCols]
    dfSklearnRegions = dfSklearnRegions.sort_values(by='Date',ascending=True).copy()
    dfSklearnRegions = filterNan(dfSklearnRegions, dropType)
    
    xtrain,ytrain,xtest,ytest = train_test_split2(dfSklearnRegions,tempTournamentId,currentTarget)
    
    bestModelAbs = (regionsStats[regionsStats['region']==region])['accuracy_2'].iloc[0]
    for model in range(len(base_models)):
        base_model = base_models[model]
        base_model.fit(xtrain, ytrain)
        pred = base_model.predict(xtest)

        testdf = pd.DataFrame([list(ytest),list(pred)]).transpose()
        testdf.columns=['yteste','pred']

        metricModelAbs = round(skm.mean_absolute_error(testdf['yteste'], testdf['pred']),2)
        if metricModelAbs<bestModelAbs or np.isnan(bestModelAbs):
            bestModelAbs=metricModelAbs
            bestModel=model
        print(f'model {model} -> {metricModelAbs}')

    regionsStats['model'][n] = bestModel
    regionsStats['accuracy_2'][n] = bestModelAbs
    
    print(f'\naccuracy: {bestModelAbs}')
    print(f'best model: {bestModel}\n')
    
printFinalResults(regionsStats, 'accuracy_2')

hide_toggle()
# Out:
# =========
#
# [1 of 22] region LPL -> 6.54:
#
# current model: 4
#
# train len: 4556
# train len no outliers: 3451
# percent of len removed: 24.25%
# test len: 329
#
# model 0 -> 6.52
# model 1 -> 6.57
# model 2 -> 6.62
# model 3 -> 6.53
# model 4 -> 6.54
# model 5 -> 6.53
# model 6 -> 6.53
# model 7 -> 6.76
# model 8 -> 6.69
#
# accuracy: 6.52
# best model: 0
#
# =========
#
# [2 of 22] region LCK -> 5.67:
#
# current model: 4
#
# train len: 4352
# train len no outliers: 3236
# percent of len removed: 25.64%
# test len: 248
#
# model 0 -> 5.71
# model 1 -> 5.84
# model 2 -> 5.84
# model 3 -> 5.71
# model 4 -> 5.67
# model 5 -> 5.76
# model 6 -> 5.72
# model 7 -> 5.8
# model 8 -> 5.72
#
# accuracy: 5.67
# best model: 4
#
# =========
#
# [3 of 22] region PCS -> 6.1:
#
# current model: 4
#
# train len: 5344
# train len no outliers: 4085
# percent of len removed: 23.56%
# test len: 105
#
# model 0 -> 6.3
# model 1 -> 6.13
# model 2 -> 6.14
# model 3 -> 6.2
# model 4 -> 6.1
# model 5 -> 6.21
# model 6 -> 6.03
# model 7 -> 6.39
# model 8 -> 6.08
#
# accuracy: 6.03
# best model: 6
#
# =========
#
# [4 of 22] region VCS -> 6.11:
#
# current model: 4
#
# train len: 5800
# train len no outliers: 4213
# percent of len removed: 27.36%
# test len: 92
#
# model 0 -> 6.14
# model 1 -> 6.15
# model 2 -> 6.14
# model 3 -> 6.18
# model 4 -> 6.11
# model 5 -> 6.18
# model 6 -> 6.16
# model 7 -> 6.26
# model 8 -> 6.23
#
# accuracy: 6.11
# best model: 4
#
# =========
#
# [5 of 22] region Ultraliga -> 7.04:
#
# current model: 4
#
# train len: 6079
# train len no outliers: 4684
# percent of len removed: 22.95%
# test len: 108
#
# model 0 -> 7.15
# model 1 -> 7.11
# model 2 -> 7.1
# model 3 -> 7.18
# model 4 -> 7.05
# model 5 -> 7.08
# model 6 -> 7.23
# model 7 -> 7.58
# model 8 -> 7.18
#
# accuracy: 7.05
# best model: 4
#
# =========
#
# [6 of 22] region LLA -> 6.38:
#
# current model: 4
#
# train len: 3658
# train len no outliers: 2715
# percent of len removed: 25.78%
# test len: 79
#
# model 0 -> 6.42
# model 1 -> 6.44
# model 2 -> 6.49
# model 3 -> 6.41
# model 4 -> 6.38
# model 5 -> 6.67
# model 6 -> 6.59
# model 7 -> 7.0
# model 8 -> 6.53
#
# accuracy: 6.38
# best model: 4
#
# =========
#
# [7 of 22] region TCL -> 6.33:
#
# current model: 4
#
# train len: 7394
# train len no outliers: 5522
# percent of len removed: 25.32%
# test len: 69
#
# model 0 -> 6.29
# model 1 -> 6.35
# model 2 -> 6.36
# model 3 -> 6.35
# model 4 -> 6.33
# model 5 -> 6.44
# model 6 -> 6.34
# model 7 -> 6.46
# model 8 -> 6.38
#
# accuracy: 6.29
# best model: 0
#
# =========
#
# [8 of 22] region LFL -> 5.8:
#
# current model: 4
#
# train len: 7752
# train len no outliers: 5742
# percent of len removed: 25.93%
# test len: 204
#
# model 0 -> 5.86
# model 1 -> 5.87
# model 2 -> 5.92
# model 3 -> 5.97
# model 4 -> 5.8
# model 5 -> 5.97
# model 6 -> 5.98
# model 7 -> 5.97
# model 8 -> 5.91
#
# accuracy: 5.8
# best model: 4
#
# =========
#
# [9 of 22] region Prime -> 5.55:
#
# current model: 4
#
# train len: 5687
# train len no outliers: 4192
# percent of len removed: 26.29%
# test len: 110
#
# model 0 -> 5.61
# model 1 -> 5.62
# model 2 -> 5.64
# model 3 -> 5.61
# model 4 -> 5.55
# model 5 -> 5.65
# model 6 -> 5.6
# model 7 -> 5.94
# model 8 -> 5.64
#
# accuracy: 5.55
# best model: 4
#
# =========
#
# [10 of 22] region LJL -> 5.43:
#
# current model: 4
#
# train len: 3368
# train len no outliers: 2544
# percent of len removed: 24.47%
# test len: 133
#
# model 0 -> 5.45
# model 1 -> 5.52
# model 2 -> 5.51
# model 3 -> 5.5
# model 4 -> 5.45
# model 5 -> 5.59
# model 6 -> 5.38
# model 7 -> 5.8
# model 8 -> 5.44
#
# accuracy: 5.38
# best model: 6
#
# =========
#
# [11 of 22] region NLC -> 7.91:
#
# current model: 4
#
# train len: 3838
# train len no outliers: 2959
# percent of len removed: 22.9%
# test len: 70
#
# model 0 -> 8.1
# model 1 -> 8.04
# model 2 -> 8.07
# model 3 -> 7.83
# model 4 -> 7.91
# model 5 -> 8.24
# model 6 -> 7.69
# model 7 -> 8.02
# model 8 -> 7.89
#
# accuracy: 7.69
# best model: 6
#
# =========
#
# [12 of 22] region CBLOL_Tier2 -> 6.51:
#
# current model: 4
#
# train len: 2471
# train len no outliers: 1877
# percent of len removed: 24.04%
# test len: 90
#
# model 0 -> 6.74
# model 1 -> 6.53
# model 2 -> 6.54
# model 3 -> 6.61
# model 4 -> 6.51
# model 5 -> 6.64
# model 6 -> 6.57
# model 7 -> 6.89
# model 8 -> 6.62
#
# accuracy: 6.51
# best model: 4
#
# =========
#
# [13 of 22] region EBL -> 6.27:
#
# current model: 4
#
# train len: 2927
# train len no outliers: 2192
# percent of len removed: 25.11%
# test len: 69
#
# model 0 -> 6.24
# model 1 -> 6.38
# model 2 -> 6.33
# model 3 -> 6.3
# model 4 -> 6.27
# model 5 -> 6.51
# model 6 -> 6.34
# model 7 -> 6.81
# model 8 -> 6.43
#
# accuracy: 6.24
# best model: 0
#
# =========
#
# [14 of 22] region Hitpoint_Tier2 -> 8.65:
#
# current model: 4
#
# train len: 4949
# train len no outliers: 3821
# percent of len removed: 22.79%
# test len: 63
#
# model 0 -> 8.92
# model 1 -> 8.77
# model 2 -> 8.78
# model 3 -> 8.67
# model 4 -> 8.68
# model 5 -> 8.91
# model 6 -> 8.68
# model 7 -> 9.04
# model 8 -> 8.78
#
# accuracy: 8.67
# best model: 3
#
# =========
#
# [15 of 22] region Elite_Tier2 -> 8.14:
#
# current model: 4
#
# train len: 1963
# train len no outliers: 1479
# percent of len removed: 24.66%
# test len: 65
#
# model 0 -> 8.35
# model 1 -> 8.19
# model 2 -> 8.19
# model 3 -> 8.32
# model 4 -> 8.18
# model 5 -> 8.34
# model 6 -> 8.34
# model 7 -> 8.49
# model 8 -> 8.25
#
# accuracy: 8.18
# best model: 4
#
# =========
#
# [16 of 22] region GLL -> 5.95:
#
# current model: 4
#
# train len: 4998
# train len no outliers: 3733
# percent of len removed: 25.31%
# test len: 69
#
# model 0 -> 6.07
# model 1 -> 5.96
# model 2 -> 5.97
# model 3 -> 6.02
# model 4 -> 5.95
# model 5 -> 6.02
# model 6 -> 6.05
# model 7 -> 6.37
# model 8 -> 5.98
#
# accuracy: 5.95
# best model: 4
#
# =========
#
# [17 of 22] region LEC -> 6.39:
#
# current model: 4
#
# train len: 11126
# train len no outliers: 8511
# percent of len removed: 23.5%
# test len: 130
#
# model 0 -> 6.4
# model 1 -> 6.39
# model 2 -> 6.4
# model 3 -> 6.41
# model 4 -> 6.42
# model 5 -> 6.51
# model 6 -> 6.45
# model 7 -> 6.61
# model 8 -> 6.45
#
# accuracy: 6.39
# best model: 1
#
# =========
#
# [18 of 22] region CBLOL -> 6.46:
#
# current model: 4
#
# train len: 6280
# train len no outliers: 4776
# percent of len removed: 23.95%
# test len: 90
#
# model 0 -> 6.61
# model 1 -> 6.52
# model 2 -> 6.52
# model 3 -> 6.6
# model 4 -> 6.47
# model 5 -> 6.48
# model 6 -> 6.6
# model 7 -> 6.66
# model 8 -> 6.54
#
# accuracy: 6.47
# best model: 4
#
# =========
#
# [19 of 22] region LPLOL -> 7.05:
#
# current model: 4
#
# train len: 8200
# train len no outliers: 6044
# percent of len removed: 26.29%
# test len: 67
#
# model 0 -> 7.18
# model 1 -> 7.23
# model 2 -> 7.25
# model 3 -> 7.41
# model 4 -> 7.05
# model 5 -> 7.02
# model 6 -> 7.51
# model 7 -> 7.52
# model 8 -> 7.21
#
# accuracy: 7.02
# best model: 5
#
# =========
#
# [20 of 22] region LCS -> 5.53:
#
# current model: 4
#
# train len: 2104
# train len no outliers: 1615
# percent of len removed: 23.24%
# test len: 93
#
# model 0 -> 5.63
# model 1 -> 5.61
# model 2 -> 5.58
# model 3 -> 5.68
# model 4 -> 5.53
# model 5 -> 5.63
# model 6 -> 5.64
# model 7 -> 5.87
# model 8 -> 5.5
#
# accuracy: 5.5
# best model: 8
#
# =========
#
# [21 of 22] region PG -> 7.73:
#
# current model: 4
#
# train len: 2698
# train len no outliers: 2086
# percent of len removed: 22.68%
# test len: 68
#
# model 0 -> 8.04
# model 1 -> 7.83
# model 2 -> 7.89
# model 3 -> 8.0
# model 4 -> 7.73
# model 5 -> 7.83
# model 6 -> 7.91
# model 7 -> 8.48
# model 8 -> 7.99
#
# accuracy: 7.73
# best model: 4
#
# =========
#
# [22 of 22] region LCO -> 5.93:
#
# current model: 4
#
# train len: 10356
# train len no outliers: 7849
# percent of len removed: 24.21%
# test len: 23
#
# model 0 -> 6.23
# model 1 -> 6.16
# model 2 -> 6.15
# model 3 -> 6.18
# model 4 -> 5.93
# model 5 -> 6.38
# model 6 -> 6.26
# model 7 -> 6.76
# model 8 -> 6.14
#
# accuracy: 5.93
# best model: 4
#
# ===============================
#
# mean accuracy: 6.503
# avg df len: 5376.090909090909
#
# CPU times: total: 18min 38s
# Wall time: 5min 18s
#         <script>
#             function code_toggle_4209945903842246637() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_4209945903842246637()">Toggle show/hide</a>

# %% [markdown]
# # THRESHOLDS

# %%
fill=0.0

regionsStats['accuracy_3']=fill
regionsStats['ceiling']=fill
regionsStats['ceilingWin']=fill
regionsStats['ceilingPer']=fill
regionsStats['ceilingLimit']=fill
regionsStats['floor']=fill
regionsStats['floorWin']=fill
regionsStats['floorPer']=fill
regionsStats['floorLimit']=fill
regionsStats['size']=fill
regionsStats['meanPred']=fill

fB = 24.5
cB = 27.5
regionsStats['topBase'] = cB
regionsStats['botBase'] = fB

bases = ([
        
        ])

bases = pd.DataFrame(bases, columns=['Region','botBase','topBase'])

for x in range(len(bases)):
    regionsStats['botBase'][bases['Region'][x]] = bases['botBase'][x]
    regionsStats['topBase'][bases['Region'][x]] = bases['topBase'][x]

hide_toggle()
# Out:
#         <script>
#             function code_toggle_10151194090476713596() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_10151194090476713596()">Toggle show/hide</a>

# %%
# %%time

for reg,region in enumerate(regionsStats['region']):
    print('================================')
    print(f'{reg}/{region}')

    regionsStats['accuracy_3'][reg]=fill
    bestDropType = regionsStats['drop_nan_type'][reg]
    
    region_model_number = (regionsStats[regionsStats['region']==region])['model'].iloc[0]
    region_model = base_models[region_model_number]
    regionDataList = regionsTrainData[region]

    tempTournamentId = region+currentSemesterYear
    dfSklearnRegions = dfToSplit[dfToSplit['TournamentRegion'].isin(regionDataList)].copy()
    dfSklearnRegions = dfSklearnRegions[regionsFeatureCols[region]+infoCols]
    dfSklearnRegions = dfSklearnRegions.sort_values(by='Date',ascending=True).copy()
    dfSklearnRegions = filterNan(dfSklearnRegions, dropType)
    
    xtrain,ytrain,xtest,ytest = train_test_split2(dfSklearnRegions,tempTournamentId,currentTarget)
    xval=xtest
    yval=ytest

    for col in ['ceiling','floor']:
        
        print(col)
        regionsStats[col][reg] = 0.0
        regionsStats[f'{col}Win'][reg] = 0.0
        regionsStats[f'{col}Per'][reg] = 0.0
        regionsStats['meanPred'][reg] = 0.0
        
        for dataX,dataY in zip(['xt','xv'],['yt','yv']):
        
            if dataX=='xt': dataX=xtest.reset_index(drop=True)
            elif dataX=='xv': dataX=xval.reset_index(drop=True)

            if dataY=='yt': dataY=ytest.reset_index(drop=True)
            elif dataY=='yv': dataY=yval.reset_index(drop=True)
    
            base_model = region_model
            base_model.fit(xtrain, ytrain)

            ceilingtest = pd.DataFrame(columns=[0,1,2,3])
            if col=='ceiling': ceilingtest[0] = [i/100 for i in range(-400,200)]
            else: ceilingtest[0] = [i/100 for i in range(-300,100)]
            for x in [1,2,3]:
                ceilingtest[x] = 0
            
            meanErr=[]
            for contMean in list(range(0,10)):
                errors,predictions = evaluate1(base_model,dataX,dataY)
                
                meanErr.append(np.mean([abs(x) for x in errors]))

                errors=list(errors)
                predictions=list(predictions)

                for n in range(len(ceilingtest)):
                    tp,tests = evaluate2(predictions,dataY,ceilingtest[0][n],col,regionsStats['botBase'][reg],regionsStats['topBase'][reg],-1)
                    
                    ceilingtest[1][n] = (float(tp))+ceilingtest[1][n]
                    ceilingtest[2][n] = (tests*100)+ceilingtest[2][n]
                    ceilingtest[3][n] = ((ceilingtest[1][n]+ceilingtest[2][n])/2)+ceilingtest[3][n]
            
            meanErr=np.mean(meanErr)
            
            print('meanerr old')
            print(regionsStats['accuracy_2'][reg])
            print('meanerr')
            print(meanErr)
            print('========')
            regionsStats['accuracy_3'][reg] += meanErr
                    
            
            for x in [1,2,3]:
                ceilingtest[x] = ceilingtest[x]/10

            filterPerc = ceilingtest.loc[(ceilingtest[2]>20) & (ceilingtest[1]>=80)].copy()
            if len(filterPerc)<1: filterPerc = ceilingtest.loc[(ceilingtest[1]>=80)].copy()
            if len(filterPerc)<1: filterPerc = ceilingtest.loc[(ceilingtest[1]==max(ceilingtest[1]))].copy()


            regionsStats['meanPred'][reg] = round(np.mean(predictions)+regionsStats['meanPred'][reg],2)
            regionsStats[col][reg] = ((filterPerc[filterPerc[1]==max(filterPerc[1])].reset_index())[0][0])+regionsStats[col][reg]
            regionsStats[f'{col}Win'][reg] = round((filterPerc[filterPerc[3]==max(filterPerc[3])].reset_index())[1][0]+regionsStats[f'{col}Win'][reg],2)
            regionsStats[f'{col}Per'][reg] = round((filterPerc[filterPerc[3]==max(filterPerc[3])].reset_index())[2][0]+regionsStats[f'{col}Per'][reg],2)

            regionsStats['size'][reg] = len(predictions)
            if col=='ceiling':
                regionsStats[f'{col}Limit'][reg] = float(ceilingtest.loc[ceilingtest[1]==max(ceilingtest[1])][0][-1:])
            else:regionsStats[f'{col}Limit'][reg] = float(ceilingtest.loc[ceilingtest[1]==max(ceilingtest[1])][0].iloc[0])

        regionsStats[col][reg] = round(regionsStats[col][reg]/2,2)
        regionsStats[f'{col}Win'][reg] = round(regionsStats[f'{col}Win'][reg]/2,2)
        regionsStats[f'{col}Per'][reg] = round(regionsStats[f'{col}Per'][reg]/2,2)
        regionsStats['meanPred'][reg] = round(regionsStats['meanPred'][reg]/2,2)
        
    regionsStats['accuracy_3'][reg] = round(regionsStats['accuracy_3'][reg]/4,2)
    print(regionsStats['accuracy_3'][reg])
try:
    hyperParams.reset_index(inplace=True)
    hyperParams.index = hyperParams['n']
except:True

hide_toggle()
# Out:
# ================================
# 0/LPL
# train len: 4556
# train len no outliers: 3451
# percent of len removed: 24.25%
# test len: 329
#
# ceiling
# meanerr old
# 6.52
# meanerr
# 6.502733612076303
# ========
# meanerr old
# 6.52
# meanerr
# 6.5353958476882585
# ========
# floor
# meanerr old
# 6.52
# meanerr
# 6.527467130369733
# ========
# meanerr old
# 6.52
# meanerr
# 6.533013026576289
# ========
# 6.52
# ================================
# 1/LCK
# train len: 4352
# train len no outliers: 3236
# percent of len removed: 25.64%
# test len: 248
#
# ceiling
# meanerr old
# 5.67
# meanerr
# 5.6705709020658635
# ========
# meanerr old
# 5.67
# meanerr
# 5.6705709020658635
# ========
# floor
# meanerr old
# 5.67
# meanerr
# 5.6705709020658635
# ========
# meanerr old
# 5.67
# meanerr
# 5.6705709020658635
# ========
# 5.67
# ================================
# 2/PCS
# train len: 5344
# train len no outliers: 4085
# percent of len removed: 23.56%
# test len: 105
#
# ceiling
# meanerr old
# 6.03
# meanerr
# 6.0340279366177985
# ========
# meanerr old
# 6.03
# meanerr
# 6.0340279366177985
# ========
# floor
# meanerr old
# 6.03
# meanerr
# 6.0340279366177985
# ========
# meanerr old
# 6.03
# meanerr
# 6.0340279366177985
# ========
# 6.03
# ================================
# 3/VCS
# train len: 5800
# train len no outliers: 4213
# percent of len removed: 27.36%
# test len: 92
#
# ceiling
# meanerr old
# 6.11
# meanerr
# 6.107439312813321
# ========
# meanerr old
# 6.11
# meanerr
# 6.107439312813321
# ========
# floor
# meanerr old
# 6.11
# meanerr
# 6.107439312813321
# ========
# meanerr old
# 6.11
# meanerr
# 6.107439312813321
# ========
# 6.11
# ================================
# 4/Ultraliga
# train len: 6079
# train len no outliers: 4684
# percent of len removed: 22.95%
# test len: 108
#
# ceiling
# meanerr old
# 7.05
# meanerr
# 7.051983715136144
# ========
# meanerr old
# 7.05
# meanerr
# 7.051983715136144
# ========
# floor
# meanerr old
# 7.05
# meanerr
# 7.051983715136144
# ========
# meanerr old
# 7.05
# meanerr
# 7.051983715136144
# ========
# 7.05
# ================================
# 5/LLA
# train len: 3658
# train len no outliers: 2715
# percent of len removed: 25.78%
# test len: 79
#
# ceiling
# meanerr old
# 6.38
# meanerr
# 6.3756999863561665
# ========
# meanerr old
# 6.38
# meanerr
# 6.3756999863561665
# ========
# floor
# meanerr old
# 6.38
# meanerr
# 6.3756999863561665
# ========
# meanerr old
# 6.38
# meanerr
# 6.3756999863561665
# ========
# 6.38
# ================================
# 6/TCL
# train len: 7394
# train len no outliers: 5522
# percent of len removed: 25.32%
# test len: 69
#
# ceiling
# meanerr old
# 6.29
# meanerr
# 6.297169818284855
# ========
# meanerr old
# 6.29
# meanerr
# 6.322935113480128
# ========
# floor
# meanerr old
# 6.29
# meanerr
# 6.310186417566714
# ========
# meanerr old
# 6.29
# meanerr
# 6.2882623180843495
# ========
# 6.3
# ================================
# 7/LFL
# train len: 7752
# train len no outliers: 5742
# percent of len removed: 25.93%
# test len: 204
#
# ceiling
# meanerr old
# 5.8
# meanerr
# 5.803470628514569
# ========
# meanerr old
# 5.8
# meanerr
# 5.803470628514569
# ========
# floor
# meanerr old
# 5.8
# meanerr
# 5.803470628514569
# ========
# meanerr old
# 5.8
# meanerr
# 5.803470628514569
# ========
# 5.8
# ================================
# 8/Prime
# train len: 5687
# train len no outliers: 4192
# percent of len removed: 26.29%
# test len: 110
#
# ceiling
# meanerr old
# 5.55
# meanerr
# 5.554783827318146
# ========
# meanerr old
# 5.55
# meanerr
# 5.554783827318146
# ========
# floor
# meanerr old
# 5.55
# meanerr
# 5.554783827318146
# ========
# meanerr old
# 5.55
# meanerr
# 5.554783827318146
# ========
# 5.55
# ================================
# 9/LJL
# train len: 3368
# train len no outliers: 2544
# percent of len removed: 24.47%
# test len: 133
#
# ceiling
# meanerr old
# 5.38
# meanerr
# 5.384224734342608
# ========
# meanerr old
# 5.38
# meanerr
# 5.384224734342608
# ========
# floor
# meanerr old
# 5.38
# meanerr
# 5.384224734342608
# ========
# meanerr old
# 5.38
# meanerr
# 5.384224734342608
# ========
# 5.38
# ================================
# 10/NLC
# train len: 3838
# train len no outliers: 2959
# percent of len removed: 22.9%
# test len: 70
#
# ceiling
# meanerr old
# 7.69
# meanerr
# 7.687565740537164
# ========
# meanerr old
# 7.69
# meanerr
# 7.687565740537164
# ========
# floor
# meanerr old
# 7.69
# meanerr
# 7.687565740537164
# ========
# meanerr old
# 7.69
# meanerr
# 7.687565740537164
# ========
# 7.69
# ================================
# 11/CBLOL_Tier2
# train len: 2471
# train len no outliers: 1877
# percent of len removed: 24.04%
# test len: 90
#
# ceiling
# meanerr old
# 6.51
# meanerr
# 6.514656744254959
# ========
# meanerr old
# 6.51
# meanerr
# 6.514656744254959
# ========
# floor
# meanerr old
# 6.51
# meanerr
# 6.514656744254959
# ========
# meanerr old
# 6.51
# meanerr
# 6.514656744254959
# ========
# 6.51
# ================================
# 12/EBL
# train len: 2927
# train len no outliers: 2192
# percent of len removed: 25.11%
# test len: 69
#
# ceiling
# meanerr old
# 6.24
# meanerr
# 6.187760209332636
# ========
# meanerr old
# 6.24
# meanerr
# 6.20235941145407
# ========
# floor
# meanerr old
# 6.24
# meanerr
# 6.250585009059579
# ========
# meanerr old
# 6.24
# meanerr
# 6.2587634019892775
# ========
# 6.22
# ================================
# 13/Hitpoint_Tier2
# train len: 4949
# train len no outliers: 3821
# percent of len removed: 22.79%
# test len: 63
#
# ceiling
# meanerr old
# 8.67
# meanerr
# 8.672222325333546
# ========
# meanerr old
# 8.67
# meanerr
# 8.672222325333546
# ========
# floor
# meanerr old
# 8.67
# meanerr
# 8.672222325333546
# ========
# meanerr old
# 8.67
# meanerr
# 8.672222325333546
# ========
# 8.67
# ================================
# 14/Elite_Tier2
# train len: 1963
# train len no outliers: 1479
# percent of len removed: 24.66%
# test len: 65
#
# ceiling
# meanerr old
# 8.18
# meanerr
# 8.18482012810519
# ========
# meanerr old
# 8.18
# meanerr
# 8.18482012810519
# ========
# floor
# meanerr old
# 8.18
# meanerr
# 8.18482012810519
# ========
# meanerr old
# 8.18
# meanerr
# 8.18482012810519
# ========
# 8.18
# ================================
# 15/GLL
# train len: 4998
# train len no outliers: 3733
# percent of len removed: 25.31%
# test len: 69
#
# ceiling
# meanerr old
# 5.95
# meanerr
# 5.953080728339859
# ========
# meanerr old
# 5.95
# meanerr
# 5.953080728339859
# ========
# floor
# meanerr old
# 5.95
# meanerr
# 5.953080728339859
# ========
# meanerr old
# 5.95
# meanerr
# 5.953080728339859
# ========
# 5.95
# ================================
# 16/LEC
# train len: 11126
# train len no outliers: 8511
# percent of len removed: 23.5%
# test len: 130
#
# ceiling
# meanerr old
# 6.39
# meanerr
# 6.392499255643267
# ========
# meanerr old
# 6.39
# meanerr
# 6.392499255643267
# ========
# floor
# meanerr old
# 6.39
# meanerr
# 6.392499255643267
# ========
# meanerr old
# 6.39
# meanerr
# 6.392499255643267
# ========
# 6.39
# ================================
# 17/CBLOL
# train len: 6280
# train len no outliers: 4776
# percent of len removed: 23.95%
# test len: 90
#
# ceiling
# meanerr old
# 6.47
# meanerr
# 6.465327763957883
# ========
# meanerr old
# 6.47
# meanerr
# 6.465327763957883
# ========
# floor
# meanerr old
# 6.47
# meanerr
# 6.465327763957883
# ========
# meanerr old
# 6.47
# meanerr
# 6.465327763957883
# ========
# 6.47
# ================================
# 18/LPLOL
# train len: 8200
# train len no outliers: 6044
# percent of len removed: 26.29%
# test len: 67
#
# ceiling
# meanerr old
# 7.02
# meanerr
# 7.024790428648844
# ========
# meanerr old
# 7.02
# meanerr
# 7.024790428648844
# ========
# floor
# meanerr old
# 7.02
# meanerr
# 7.024790428648844
# ========
# meanerr old
# 7.02
# meanerr
# 7.024790428648844
# ========
# 7.02
# ================================
# 19/LCS
# train len: 2104
# train len no outliers: 1615
# percent of len removed: 23.24%
# test len: 93
#
# ceiling
# meanerr old
# 5.5
# meanerr
# 5.493237684060263
# ========
# meanerr old
# 5.5
# meanerr
# 5.534795709965065
# ========
# floor
# meanerr old
# 5.5
# meanerr
# 5.564051689350075
# ========
# meanerr old
# 5.5
# meanerr
# 5.518549360734843
# ========
# 5.53
# ================================
# 20/PG
# train len: 2698
# train len no outliers: 2086
# percent of len removed: 22.68%
# test len: 68
#
# ceiling
# meanerr old
# 7.73
# meanerr
# 7.733021032478719
# ========
# meanerr old
# 7.73
# meanerr
# 7.733021032478719
# ========
# floor
# meanerr old
# 7.73
# meanerr
# 7.733021032478719
# ========
# meanerr old
# 7.73
# meanerr
# 7.733021032478719
# ========
# 7.73
# ================================
# 21/LCO
# train len: 10356
# train len no outliers: 7849
# percent of len removed: 24.21%
# test len: 23
#
# ceiling
# meanerr old
# 5.93
# meanerr
# 5.934783331468796
# ========
# meanerr old
# 5.93
# meanerr
# 5.934783331468796
# ========
# floor
# meanerr old
# 5.93
# meanerr
# 5.934783331468796
# ========
# meanerr old
# 5.93
# meanerr
# 5.934783331468796
# ========
# 5.93
# CPU times: total: 9min 25s
# Wall time: 4min 29s
#         <script>
#             function code_toggle_16519786875505738753() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_16519786875505738753()">Toggle show/hide</a>

# %%
print(np.mean(regionsStats['accuracy_0']))
print(np.mean(regionsStats['accuracy_1']))
print(np.mean(regionsStats['accuracy_2']))
regionsStats
# Out:
# 6.550454545454546
# 6.521363636363635
# 6.502727272727273
#             region  model   size  accuracy_0  accuracy_1  accuracy_2  \
# 0              LPL      0  329.0        6.59        6.54        6.52
# 1              LCK      4  248.0        5.69        5.67        5.67
# 2              PCS      6  105.0        6.13        6.10        6.03
# 3              VCS      4   92.0        6.12        6.11        6.11
# 4        Ultraliga      4  108.0        7.04        7.04        7.05
# 5              LLA      4   79.0        6.44        6.38        6.38
# 6              TCL      0   69.0        6.39        6.33        6.29
# 7              LFL      4  204.0        5.80        5.80        5.80
# 8            Prime      4  110.0        5.57        5.55        5.55
# 9              LJL      6  133.0        5.43        5.43        5.38
# 10             NLC      6   70.0        7.97        7.91        7.69
# 11     CBLOL_Tier2      4   90.0        6.51        6.51        6.51
# 12             EBL      0   69.0        6.31        6.27        6.24
# 13  Hitpoint_Tier2      3   63.0        8.65        8.65        8.67
# 14     Elite_Tier2      4   65.0        8.14        8.14        8.18
# 15             GLL      4   69.0        6.01        5.95        5.95
# 16             LEC      1  130.0        6.39        6.39        6.39
# 17           CBLOL      4   90.0        6.46        6.46        6.47
# 18           LPLOL      5   67.0        7.13        7.05        7.02
# 19             LCS      8   93.0        5.55        5.53        5.50
# 20              PG      4   68.0        7.77        7.73        7.73
# 21             LCO      4   23.0        6.02        5.93        5.93
#
#     drop_nan_type  accuracy_3  ceiling  ceilingWin  ceilingPer  ceilingLimit  \
# 0               1        6.52     1.78       62.83        4.11          1.94
# 1               0        5.67     0.20       46.30       21.77          0.20
# 2               0        6.03     0.80       91.67       11.43          0.84
# 3               0        6.11     1.32       80.00        5.43          1.34
# 4               0        7.05     0.30       80.56       66.67          1.90
# 5               0        6.38     0.59       80.00        6.33          0.60
# 6               0        6.30     1.27      100.00        1.45          1.45
# 7               0        5.80     0.19       80.36       27.45          1.70
# 8               0        5.55     0.43       80.00       45.45          1.04
# 9               0        5.38     1.11      100.00        1.50          1.81
# 10              0        7.69     0.45       82.61       32.86          1.99
# 11              0        6.51     0.84      100.00        6.67          1.30
# 12              0        6.22     0.77       74.46       19.57          1.99
# 13              0        8.67     0.87       80.00       39.68          0.87
# 14              0        8.18     0.51      100.00        4.62          0.76
# 15              0        5.95     0.28       78.95       27.54          0.28
# 16              0        6.39     0.35       71.43        5.38          0.36
# 17              0        6.47     0.33       94.74       21.11          0.90
# 18              0        7.02     0.72       81.82       32.84          1.99
# 19              0        5.53     0.90       64.92       18.82          0.41
# 20              0        7.73     0.81      100.00       13.24          1.99
# 21              1        5.93     0.21       83.33       26.09          1.33
#
#     floor  floorWin  floorPer  floorLimit  meanPred  topBase  botBase
# 0   -2.16     81.09      3.65       -1.73     25.53     27.5     24.5
# 1   -0.18     80.65    100.00       -0.29     22.66     27.5     24.5
# 2   -1.65    100.00      3.81       -1.65     24.48     27.5     24.5
# 3   -1.91     80.00      5.43       -1.91     26.80     27.5     24.5
# 4   -1.09    100.00      3.70       -1.09     28.53     27.5     24.5
# 5   -0.30     81.82     41.77       -0.46     24.23     27.5     24.5
# 6   -1.00    100.00      3.62       -0.99     24.82     27.5     24.5
# 7   -0.86    100.00      0.49       -0.86     26.25     27.5     24.5
# 8   -1.50    100.00      0.91       -1.50     26.26     27.5     24.5
# 9   -0.22     80.26     57.14       -1.05     24.55     27.5     24.5
# 10  -0.43     86.67     21.43       -0.43     26.93     27.5     24.5
# 11  -1.12    100.00      1.11       -1.12     29.26     27.5     24.5
# 12  -1.74    100.00      3.62       -1.66     25.60     27.5     24.5
# 13  -2.32    100.00      4.76       -2.32     28.12     27.5     24.5
# 14  -0.47     55.56     13.85       -0.47     28.92     27.5     24.5
# 15   0.29     50.98     73.91        0.29     28.47     27.5     24.5
# 16  -0.48    100.00      1.54       -0.48     27.10     27.5     24.5
# 17  -1.39    100.00      1.11       -1.39     26.32     27.5     24.5
# 18  -0.52     67.74     46.27       -0.52     27.20     27.5     24.5
# 19  -0.80     83.48     20.97       -2.29     23.68     27.5     24.5
# 20  -1.17     83.33      8.82       -1.17     29.07     27.5     24.5
# 21  -0.17     81.82     47.83       -1.45     25.75     27.5     24.5

# %% [markdown]
# # SAVE

# %%
regionsStats.to_pickle("./Data/raw_data/regionsStats.pkl")

for data,dataName in zip([regionsFeatureCols,regionsTrainData],['regionsFeatureCols','regionsTrainData']):
    with open(f'./Data/raw_data/{dataName}.json', 'w') as fp:
        json.dump(data, fp, indent=4)

# %% [markdown]
# # Notes

# %%
# %%time

# regionsTrainData = dict(zip(regionsList,[0]*len(regionsList)))
# for key in regionsTrainData:
#     regionsTrainData[key] = regionsToFeed.copy()
    
# regionsStats['accuracy_0'] = np.nan

# for n,region in enumerate(regionsToPredict):
#     print('=========\n')
#     regionFinalAcc = (regionsStats[regionsStats['region']==region])['accuracy_0'].iloc[0]
#     regionsToTest = regionsTrainData[region].copy()
#     regionsToTest.remove(region)
#     tempTournamentId = region+currentSemesterYear
    
#     print(f'[{n} of {len(regionsToPredict)}] region {region} -> {round(regionFinalAcc,3)}:\n')
    
#     for nn,regionToTest in enumerate(regionsToTest):
#         regionsTrainData[region].remove(regionToTest)
        
#         dfSklearnRegions = dfToSplit[dfToSplit['TournamentRegion'].isin(regionsTrainData[region])].copy()
#         dfSklearnRegions = dfSklearnRegions.sort_values(by='Date',ascending=True).copy()
        
#         xtrain,ytrain,xtest,ytest = train_test_split2(dfSklearnRegions,tempTournamentId,verbose=False)
#         region_model_number = (regionsStats[regionsStats['region']==region])['model'].iloc[0]
#         region_model = base_models[region_model_number]
#         region_model.fit(xtrain, ytrain)
#         pred = region_model.predict(xtest)
        
#         metric = skm.mean_absolute_error(ytest, pred)
#         if metric < regionFinalAcc or np.isnan(regionFinalAcc):
#             regionFinalAcc = metric
#             print(f'{round(regionFinalAcc,3)} -> {regionToTest} removed                                       ')
#         else:
#             regionsTrainData[region].append(regionToTest)
            
#         print(f'[{nn+1} of {len(regionsToTest)}] testing: {regionToTest}                        ',end='\r')
    
#     regionsStats['accuracy_0'][n] = regionFinalAcc
#     regionsStats['size'][n] = len(dfSklearnRegions)
    
#     print(f'\n\naccuracy: {round(regionFinalAcc,3)}')
#     print(f'{region} train data: {regionsTrainData[region]}\nunique regions:{len(regionsTrainData[region])}')
#     print(f'test data len: {len(pred)}\n')
    
# printFinalResults(regionsStats, 'accuracy_0')

hide_toggle()
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
#         <script>
#             function code_toggle_10446356222369744234() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_10446356222369744234()">Toggle show/hide</a>
