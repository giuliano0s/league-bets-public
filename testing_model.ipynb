# %%
import Utils.model_file as model_file
import Utils.utils_file as utils_file

import numpy as np
import pandas as pd

# %%
teste=dict()
teste2=dict()
teste[1] = teste2[2]

teste[1][2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 teste=dict()
# ----> 2 teste[1][2] = 2
#
# KeyError: 1

# %%
utils = utils_file.Utils_Class(cache_model=True, cache_scraping=True)

# %%
model = model_file.Final_Model_Class(target='Score', model_type='binary')

# %%
print(np.mean(utils.regions_stats['accuracy_0']))
print(np.mean(utils.regions_stats['accuracy_1']))
print(np.mean(utils.regions_stats['accuracy_2']))
utils.regions_stats
# Out:
# 0.33959259259259256
# 0.33048148148148143
# 0.32870370370370366
#              region  model size  accuracy_0  accuracy_1  accuracy_2  \
# 0               LPL      7  329       0.289       0.289       0.289
# 1               LCK      7  285       0.396       0.372       0.372
# 2               PCS      7  137       0.350       0.343       0.343
# 3               VCS      7  139       0.381       0.381       0.381
# 4         Ultraliga      7  112       0.375       0.339       0.339
# 5               LLA      7   98       0.327       0.327       0.327
# 6   SuperLiga_Tier2      7  115       0.357       0.357       0.357
# 7               TCL      7   79       0.418       0.405       0.405
# 8               LFL      7  225       0.396       0.396       0.396
# 9             Prime      7  115       0.383       0.383       0.383
# 10              LJL      7  133       0.256       0.256       0.256
# 11             NACL      7  234       0.393       0.385       0.385
# ...

# %%
model.print_region_teams('LJL')
# Out:
# {0: 'AXIZ', 1: 'Burning Core', 2: 'Crest Gaming Act', 3: 'Detonation FocusMe', 4: 'FENNEL', 5: 'Rascal Jester', 6: 'Sengoku Gaming', 7: 'SoftBank Hawks Gaming', 8: 'Unsold Stuff Gaming', 9: 'V3 Esports'}

# %%
model.blue_team = 3
model.red_team = 2
model.print_team_players()
# Out:
# team blue players = ['tol2', 'Steal', 'Aria', 'Yutapon', 'Harp']
# team red players = ['Nap', 'Cassin', 'Eugeo', 'Honey', 'Primo']

# %%
model.make_prediction(manual_insert=False)
# Out:
# ...
# no data names on: []
# last train data: 2023-04-02 00:00:00
# Crest Gaming Act
# ...
# no data names on: []
# last train data: 2023-04-02 00:00:00
# Crest Gaming Act
# ...
# no data names on: []
# last train data: 2023-04-02 00:00:00
# Crest Gaming Act
# ...
# no data names on: []
# last train data: 2023-04-02 00:00:00
# Crest Gaming Act
# ...
# no data names on: []
# last train data: 2023-04-02 00:00:00
# Crest Gaming Act
