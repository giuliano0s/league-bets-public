# %%
import Utils.model_file as model_file
import Utils.utils_file as utils_file

import numpy as np
import pandas as pd

# %%
Model = model_file.Final_Model_Class(target='Score', model_type='logistic')
Utils = Model.Utils

# %%
print(np.mean(Utils.regions_stats['error']))
Utils.regions_stats
# Out:
# 0.202
#              region  model test_size train_size  error  cut_off_var  \
# 0               LPL      0       626       3987  0.200          1.5
# 1               LCK      0       444       3257  0.251          1.5
# 2               PCS      0       274       2237  0.154          1.5
# 3               VCS      0       300       4918  0.232          1.5
# 4         Ultraliga      0       174       2258  0.352          1.5
# 5               LLA      0       164       2244  0.217          1.5
# 6   SuperLiga_Tier2      0       115       2705  0.323          1.5
# 7               TCL      0       161       5966  0.210          1.5
# 8               LFL      0       368       3776  0.298          1.5
# 9             Prime      0       179       3280  0.207          1.5
# 10              LJL      0       228       2495  0.165          1.5
# 11             NACL      0       234       2234  0.254          1.5
# 12              NLC      0       137       2294  0.222          1.5
# 13      CBLOL_Tier2      0       165       6427  0.221          1.5
# 14              EBL      0       114       1546  0.259          1.5
# 15        SuperLiga      0       111        286  0.380          1.5
# 16        LCK_Tier2      0       184       2808  0.152          1.5
# 17   Hitpoint_Tier2      0       121       4420  0.037          1.5
# 18      Elite_Tier2      0       114       4084  0.207          1.5
# 19              GLL      0       102       3071  0.030          1.5
# 20              LEC      0       229       4436  0.250          1.5
# 21            CBLOL      0       181       4297  0.204          1.5
# 22            LPLOL      0       111       5291  0.089          1.5
# 23              LCS      0       214       4909  0.226          1.5
# 24               PG      0       112       3250  0.152          1.5
# 25          Arabian      0        71       1967  0.130          1.5
# 26      Prime_Tier2      0       114       1495  0.125          1.5
# 27              LCO      0        97       5432  0.109          1.5
#
#     threshold  len_lost
# 0        0.35      0.42
# 1        0.35      0.52
# 2        0.35      0.62
# 3        0.35      0.48
# 4        0.35      0.69
# 5        0.35      0.63
# 6        0.35      0.46
# 7        0.35      0.61
# 8        0.35      0.64
# 9        0.35      0.68
# 10       0.35      0.52
# 11       0.35      0.46
# 12       0.35      0.54
# 13       0.35      0.53
# 14       0.35      0.49
# 15       0.35      0.29
# 16       0.35      0.57
# 17       0.35      0.78
# 18       0.35      0.75
# 19       0.35      0.68
# 20       0.35      0.63
# 21       0.35      0.70
# 22       0.35      0.59
# 23       0.35      0.71
# 24       0.35      0.41
# 25       0.35      0.68
# 26       0.35      0.93
# 27       0.35      0.43

# %%
Model.print_region_teams('LPL')
# Out:
# {0: 'Anyone s Legend', 1: 'Bilibili Gaming', 2: 'Dominus Esports', 3: 'Edward Gaming', 4: 'Funplus Phoenix', 5: 'Invictus Gaming', 6: 'JD Gaming', 7: 'LGD Gaming', 8: 'LNG Esports', 9: 'Ninjas in Pyjamas', 10: 'OMG', 11: 'Rare Atom', 12: 'Rogue Warriors', 13: 'Royal Never Give Up', 14: 'Suning', 15: 'TT', 16: 'Team WE', 17: 'Top Esports', 18: 'Ultra Prime', 19: 'Vici Gaming', 20: 'Victory Five', 21: 'Weibo Gaming', 22: 'eStar'}

# %%
Model.blue_team = 9
Model.red_team = 7
Model.print_team_players()

#team_blue_list=['Wayward', 'Tian', 'RooKie', 'JackeyLove', 'Mark']
#team_red_list=['Zika', 'Tarzan', 'Scout', 'GALA', 'Hang']
# Out:
# team_blue_list = ['invincible', 'Shad0w', 'Dream', 'Photic', 'Zhuo']
# team_red_list = ['Xiaoxu', 'Meteor', 'Haichao', 'Lpc', 'jinjiao']

# %%
team_blue_list = ['invincible', 'Shad0w', 'Angel', 'Photic', 'Zhuo']
team_red_list = ['fearness', 'Meteor', 'Haichao', 'Lpc', 'jinjiao']

# %%
Model.make_prediction(manual_insert=True, team_blue_list=team_blue_list, team_red_list=team_red_list)
# Out:
# last train data: 2023-04-14 00:00:00
# =================
# no data names on: []
# 0.11271057327809438
